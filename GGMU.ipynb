# %% [markdown]
# <a href="https://colab.research.google.com/github/jack07310-hub/KHUDA_10_ML/blob/main/GGMU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('GGMU')
# Out:
# GGMU
